# %%
import pandas as pd
import numpy as np
combinedLineData = pd.read_excel("D:/Covid_data_New/Yr2023/Jan/Jan23/test.xlsx")

mapping = {"S1":"NA","S2":"C19","S3":"C19","S4":"FluA","S5":"FluA","S6":"FluB","S7":"FluB",
"S8":"RSVAB","S9":"RSVAB"}

FluAStrong=dict()
C19Strong = dict()
FluBStrong = dict()
RSVStrong = dict()
RNasePStrong = dict()

FluAClear=dict()
C19Clear = dict()
FluBClear = dict()
RSVClear = dict()
RNasePClear = dict()

dta = []
for i in combinedLineData.index:
    sampleSet = combinedLineData.loc[i,'SampleName']
    sampleName = sampleSet
    #print(sampleName)
    if "FluA" in sampleName or "Flu A" in sampleName or "Flu B" in sampleName or "FluB" in sampleName or "RSV" in sampleName or "SARS" in sampleName:
        dta.append(sampleName)
    
    
    if sampleName == "S1":
        if 43 > float(combinedLineData.loc[i,'FLUA_CqValue']) > 38:
            RNasePStrong.setdefault("RNASEP",[]).append("FluA\tStrong")
        if 43 > float(combinedLineData.loc[i,'FLUB_CqValue']) > 37:
            RNasePStrong.setdefault("RNASEP",[]).append("FluB\tStrong")
        if 43 >float(combinedLineData.loc[i,'RSVAB_CqValue']) > 38:
            RNasePStrong.setdefault("RNASEP",[]).append("RSVAB\tStrong")
        if 43 >float(combinedLineData.loc[i,'COV19_CqValue']) > 38:
            RNasePStrong.setdefault("RNASEP",[]).append("C19\tStrong")
            

        if float(combinedLineData.loc[i,'FLUA_CqValue']) < 38:
            RNasePClear.setdefault("RNASEP",[]).append("FluA\tClear")
        if float(combinedLineData.loc[i,'FLUB_CqValue']) < 37:
            RNasePClear.setdefault("RNASEP",[]).append("FluB\tClear")
        if float(combinedLineData.loc[i,'RSVAB_CqValue']) < 38:
            RNasePClear.setdefault("RNASEP",[]).append("RSVAB\tClear")
        if float(combinedLineData.loc[i,'COV19_CqValue']) < 38:
            RNasePClear.setdefault("RNASEP",[]).append("C19\tClear")



    if sampleName == "S2" or sampleName == "S3":
        if 43 > float(combinedLineData.loc[i,'FLUA_CqValue']) > 38:
            C19Strong.setdefault("C19",[]).append("FluA\tStrong")
        if 43 > float(combinedLineData.loc[i,'FLUB_CqValue']) > 37:
            C19Strong.setdefault("C19",[]).append("FluB\tStrong")
        if 43 >float(combinedLineData.loc[i,'RSVAB_CqValue']) > 38:
            C19Strong.setdefault("C19",[]).append("RSVAB\tStrong")
        if 43 >float(combinedLineData.loc[i,'COV19_CqValue']) > 38:
            C19Strong.setdefault("C19",[]).append("C19\tStrong")
            

        if float(combinedLineData.loc[i,'FLUA_CqValue']) < 38:
            C19Clear.setdefault("C19",[]).append("FluA\tClear")
        if float(combinedLineData.loc[i,'FLUB_CqValue']) < 37:
            C19Clear.setdefault("C19",[]).append("FluB\tClear")
        if float(combinedLineData.loc[i,'RSVAB_CqValue']) < 38:
            C19Clear.setdefault("C19",[]).append("RSVAB\tClear")

        
    if sampleName == "S4" or sampleName == "S5":
        if 43 > float(combinedLineData.loc[i,'FLUA_CqValue']) > 38:
            FluAStrong.setdefault("FluA",[]).append("FluA\tStrong")
        if 43 > float(combinedLineData.loc[i,'FLUB_CqValue']) > 37:
            FluAStrong.setdefault("FluA",[]).append("FluB\tStrong")
        if 43 >float(combinedLineData.loc[i,'RSVAB_CqValue']) > 38:
            FluAStrong.setdefault("FluA",[]).append("RSVAB\tStrong")
        if 43 >float(combinedLineData.loc[i,'COV19_CqValue']) > 38:
            FluAStrong.setdefault("FluA",[]).append("C19\tStrong")
            

        if float(combinedLineData.loc[i,'COV19_CqValue']) < 38:
            FluAClear.setdefault("FluA",[]).append("C19\tClear")
        if float(combinedLineData.loc[i,'FLUB_CqValue']) < 37:
            FluAStrong.setdefault("FluA",[]).append("FluB\tClear")
        if float(combinedLineData.loc[i,'RSVAB_CqValue']) < 38:
            FluAStrong.setdefault("FluA",[]).append("RSVAB\tClear")


    if sampleName == "S6" or sampleName == "S7":
        if 43 > float(combinedLineData.loc[i,'FLUA_CqValue']) > 38:
            FluBStrong.setdefault("FluB",[]).append("FluA\tStrong")
        if 43 > float(combinedLineData.loc[i,'FLUB_CqValue']) > 37:
            FluBStrong.setdefault("FluB",[]).append("FluB\tStrong")
        if 43 >float(combinedLineData.loc[i,'RSVAB_CqValue']) > 38:
            FluBStrong.setdefault("FluB",[]).append("RSVAB\tStrong")
        if 43 >float(combinedLineData.loc[i,'COV19_CqValue']) > 38:
            FluBStrong.setdefault("FluB",[]).append("C19\tStrong")
            

        if float(combinedLineData.loc[i,'COV19_CqValue']) < 38:
            FluBClear.setdefault("FluB",[]).append("C19\tClear")
        if float(combinedLineData.loc[i,'FLUA_CqValue']) < 38:
            FluBClear.setdefault("FluB",[]).append("FluB\tClear")
        if float(combinedLineData.loc[i,'RSVAB_CqValue']) < 38:
            FluBClear.setdefault("FluB",[]).append("RSVAB\tClear")
        


    if sampleName == "S8" or sampleName == "S9":
        if 43 > float(combinedLineData.loc[i,'FLUA_CqValue']) > 38:
            RSVStrong.setdefault("RSV",[]).append("FluA\tStrong")
        if 43 > float(combinedLineData.loc[i,'FLUB_CqValue']) > 37:
            RSVStrong.setdefault("RSV",[]).append("FluB\tStrong")
        if 43 >float(combinedLineData.loc[i,'RSVAB_CqValue']) > 38:
            RSVStrong.setdefault("RSV",[]).append("RSVAB\tStrong")
        if 43 >float(combinedLineData.loc[i,'COV19_CqValue']) > 38:
            RSVStrong.setdefault("RSV",[]).append("C19\tStrong")
            

        if float(combinedLineData.loc[i,'COV19_CqValue']) < 38:
            RSVClear.setdefault("RSV",[]).append("C19\tClear")
        if float(combinedLineData.loc[i,'FLUA_CqValue']) < 38:
            RSVClear.setdefault("RSV",[]).append("FluB\tClear")
        if float(combinedLineData.loc[i,'FLUB_CqValue']) < 37:
            RSVClear.setdefault("RSV",[]).append("FluB\tClear")    
  

        
print ("C19")
for d in C19Strong:
    test = dict()
    l = 0
    clear = 0
    for v in C19Strong[d]:
        s = v.split("\t")
        test.setdefault(s[0],[]).append(s[1])
        #print(v)
    
    for i in test:
        print (i, len(test[i]))
    #print (test)

print ("\nFluA")
for d in FluAStrong:
    test = dict()
    l = 0
    clear = 0
    for v in FluAStrong[d]:
        s = v.split("\t")
        test.setdefault(s[0],[]).append(s[1])
        #print(v)
    for i in test:
        print (i, len(test[i]))
    #print (test)

print ("\nFluB")

for d in FluBStrong:
    test = dict()
    l = 0
    clear = 0
    for v in FluBStrong[d]:
        s = v.split("\t")
        test.setdefault(s[0],[]).append(s[1])
        #print(v)
    for i in test:
        print (i, len(test[i]))
    #print (test)

print ("\nRSVAB")

for d in RSVStrong:
    test = dict()
    l = 0
    clear = 0
    for v in RSVStrong[d]:
        s = v.split("\t")
        test.setdefault(s[0],[]).append(s[1])
        #print(v)
    for i in test:
        print (i, len(test[i]))
    #print (test)

print ("\nRnaseP")
for d in RNasePStrong:
    test = dict()
    l = 0
    clear = 0
    for v in RNasePStrong[d]:
        s = v.split("\t")
        test.setdefault(s[0],[]).append(s[1])
        #print(v)
    for i in test:
        print (i, len(test[i]))
    #print (test)

print("done strong")

print ("C19 clear")
for d in C19Clear:
    test = dict()
    l = 0
    clear = 0
    for v in C19Clear[d]:
        s = v.split("\t")
        test.setdefault(s[0],[]).append(s[1])
        #print(v)
    for i in test:
        print (i, len(test[i]))
    #print (test)

print ("\nFluA clear")
for d in FluAClear:
    test = dict()
    l = 0
    clear = 0
    for v in FluAClear[d]:
        s = v.split("\t")
        test.setdefault(s[0],[]).append(s[1])
        #print(v)
    for i in test:
        print (i, len(test[i]))
    #print (test)


print ("\nFluB clear")
for d in FluBClear:
    test = dict()
    l = 0
    clear = 0
    for v in FluBClear[d]:
        s = v.split("\t")
        test.setdefault(s[0],[]).append(s[1])
        #print(v)
    for i in test:
        print (i, len(test[i]))
    #print (test)


print ("\nRSV clear")
for d in RSVClear:
    test = dict()
    l = 0
    clear = 0
    for v in RSVClear[d]:
        s = v.split("\t")
        test.setdefault(s[0],[]).append(s[1])
        #print(v)
    for i in test:
        print (i, len(test[i]))
    #print (test)


print ("\nRnaseP clear")
for d in RNasePClear:
    test = dict()
    l = 0
    clear = 0
    for v in RNasePClear[d]:
        s = v.split("\t")
        test.setdefault(s[0],[]).append(s[1])
        #print(v)
    for i in test:
        print (i, len(test[i]))
    #print (test)
print("done clear")

xx = np.array(dta)
print(len(xx))
print(len(np.unique(xx)))

dd = np.unique(xx)
for d in dd:
    s = d.split(" ")
    print(s[0])
#print(xx.un)
# Out:
# C19
#
# FluA
#
# FluB
#
# RSVAB
#
# RnaseP
# done strong
# C19 clear
#
# FluA clear
#
# FluB clear
#
# RSV clear
#
# RnaseP clear
# done clear
# 2376
# 396
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_Flu
# AN_RSV-A
# AN_RSV-A
# AN_RSV-A
# AN_RSV-A
# AN_RSV-A
# AN_RSV-A
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L1
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# L2
# ...
