# %%
import json
f = open('D:/Annotations_automation/assay.json')

  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
#print(data[0]['ctCutoffs'])
for i in data:
    #print(i)
    for k in i:
        print(k,i[k])
  
# Closing file
f.close()
# Out:
# 5-27-2022
# covid
# ['covid', 'covid437']
# ['ABY', 'FAM', 'VIC', 'JUN']
# [37, 37, 37, 32]
# False
# 4.3.7
# [{'validated_inst': True, 'instrumentName': 'QS5', 'numWells': 96, 'threshold': [5000, 5000, 5000, 30000]}, {'validated_inst': True, 'instrumentName': 'QS5', 'numWells': 384, 'threshold': [5000, 5000, 5000, 30000]}, {'validated_inst': True, 'instrumentName': 'QS5DX', 'numWells': 96, 'threshold': [5000, 5000, 5000, 30000]}, {'validated_inst': True, 'instrumentName': 'QS7', 'numWells': 384, 'threshold': [4000, 4000, 4000, 24000]}, {'validated_inst': False, 'instrumentName': 'QS7PRO', 'numWells': 96, 'threshold': [5000, 5000, 5000, 30000]}, {'validated_inst': True, 'instrumentName': 'SDS_7500', 'numWells': 96, 'threshold': [10000, 10000, 10000, 60000]}, {'validated_inst': True, 'instrumentName': 'SDS_7500_FAST', 'numWells': 96, 'threshold': [10000, 10000, 10000, 60000]}]
# 5-27-2022
# gemini1
# ['gemini1', 'gemini_1', 'gemini-1', 'gemini 1']
# ['ABY', 'FAM', 'VIC', 'JUN']
# ...
